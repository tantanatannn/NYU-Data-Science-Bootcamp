# %% [markdown]
# # Data Science Bootcamp Week 4

# %% [markdown]
# **1050. Actors and Directors Who Cooperated At Least Three Times - https://leetcode.com/problems/actors-and-directors-who-cooperated-at-least-three-times/**

# %%
from IPython.display import Image, display
display(Image("1050_sql.png"))

# %%
from IPython.display import Image, display
display(Image("1050_pandas.png"))

# %% [markdown]
# **1667. Fix Names in a Table - https://leetcode.com/problems/fix-names-in-a-table/**

# %%
from IPython.display import Image, display
display(Image("1667_sql.png"))

# %%
from IPython.display import Image, display
display(Image("1667_pandas.png"))

# %% [markdown]
# **175. Combine Two Tables - https://leetcode.com/problems/combine-two-tables/**

# %%
from IPython.display import Image, display
display(Image("175_sql.png"))

# %%
from IPython.display import Image, display
display(Image("175_pandas.png"))

# %% [markdown]
# **176. Second Highest Salary - https://leetcode.com/problems/second-highest-salary/**

# %%
from IPython.display import Image, display
display(Image("176_sql.png"))

# %%
from IPython.display import Image, display
display(Image("176_pandas.png"))

# %% [markdown]
# **1327. List the Products Ordered in a Period - https://leetcode.com/problems/list-the-products-ordered-in-a-period/**

# %%
from IPython.display import Image, display
display(Image("1327_sql.png"))

# %%
from IPython.display import Image, display
display(Image("1327_pandas.png"))

# %% [markdown]
# **1378. Replace Employee ID With the Unique Identifier - https://leetcode.com/problems/replace-employee-id-with-the-unique-identifier/**

# %%
from IPython.display import Image, display
display(Image("1378_sql.png"))

# %%
from IPython.display import Image, display
display(Image("1378_pandas.png"))

# %% [markdown]
# **550. Game Play Analysis IV - https://leetcode.com/problems/game-play-analysis-iv/**

# %%
from IPython.display import Image, display
display(Image("550_sql.png"))

# %%
from IPython.display import Image, display
display(Image("550_pandas.png"))

# %% [markdown]
# **1075. Project Employees I - https://leetcode.com/problems/project-employees-i/**

# %%
from IPython.display import Image, display
display(Image("1075_sql.png"))

# %%
from IPython.display import Image, display
display(Image("1075_pandas.png"))

# %% [markdown]
# **185. Department Top Three Salaries - https://leetcode.com/problems/department-top-three-salaries/**

# %%
from IPython.display import Image, display
display(Image("185_sql.png"))

# %%
from IPython.display import Image, display
display(Image("185_pandas.png"))
